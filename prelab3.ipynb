# %% [markdown]
# # Pre-lab Assignment 3
# ## Due: Mon, 10 Feb 2025 07:30:00
#
# ### Score Information:
# - Total Points: 25
# - Total Penalties: 100
# - Penalties Graded: 0
#
# ### Academic Integrity Statement:
# By filling in your name below, you certify that:
# 1. The work on this prelab is your own
# 2. You have not copied work from any other student
# 3. You understand failing to honor this agreement will result in:
#    - ZERO score for the lab
#    - One letter drop in final course grade
#    - Possible disciplinary action
# 4. You have used only your own hardware (unless explicitly permitted)

# %%
student_name = "rpanchag" #Replace with your name

# %% [markdown]
# ### 74HC14 Parameters
# Read the transfer characteristics from section 13 of the datasheet
# For VCC = 4.5V at 25°C ambient temperature
#
# #### Enter VT+ values (V)

# %%
vt_plus_typical = 2.0  # Replace with typical value
vt_plus_min = 2.0  # Replace with minimum value
vt_plus_max = 2.0  # Replace with maximum value

# %% [markdown]
# #### Enter VT- values (V)

# %%
vt_minus_typical = 2.0  # Replace with typical value
vt_minus_min = 2.0  # Replace with minimum value
vt_minus_max = 2.0  # Replace with maximum value

# %% [markdown]
# Note: 74HC04 datasheet has no transfer characteristics section
# Normal inverter has standard input voltage thresholds
#
# ### 74HC86 Reading device characterisics from datasheets - Timing Parameters
# From section 10 (Dynamic characteristics)
# For VCC = 4.5V at 25°C ambient temperature
# #### Enter tTHL values (ns)

# %%
t_thl_typical = 0.0  # Replace with typical value
t_thl_max = 0.0  # Replace with maximum value

# %% [markdown]
# #### Enter tTLH values (ns)

# %%
t_tlh_typical = 0.0  # Replace with typical value
t_tlh_max = 0.0  # Replace with maximum value

# %% [markdown]
# #### Enter tPHL values (ns)

# %%
t_phl_typical = 0.0  # Replace with typical value
t_phl_max = 0.0  # Replace with maximum value

# %% [markdown]
# #### Enter tPLH values (ns)

# %%
t_plh_typical = 0.0  # Replace with typical value
t_plh_max = 0.0  # Replace with maximum value

# %% [markdown]
# ### 3. Estimating device parametrics [4 points]
# Consider the diagram below and answer the following questions. Round your answers to the nearest 0.1 ns.
#
# Use the 10%/90% rule to estimate rise and fall times. I.e., measure the rise time of the output as the time needed to go from the 10% level to the 90% level. (You would find that the oscilloscopes in the lab have a way of estimating this automatically.)
#
# For the propagation delay, it is always important to remember to measure it as the time from the center of the transition on the input that caused the output transition to the time of the center of the transition on the output that it causes. The propagation delay is always specified by the transition on the output. For instance, tPHL, for a NAND gate, is the delay between an input transition and a high-to-low transition of the output.
#
# What if there are two input transitions close to one another? Which input transition causes the corresponding output transition? You need to think that through and pick the right one to know how to estimate the timing.
#
# ![image.png](attachment:image.png)

# %%
t_thl_3 = 0.0  # Replace with actual value for problem 3
t_tlh_3 = 0.0  # Replace with actual value for problem 3
t_phl_3 = 0.0  # Replace with actual value for problem 3
t_plh_3 = 0.0  # Replace with actual value for problem 3

# %% [markdown]
# ### Propagation Delay Calculations
# Assume tPHL = tPLH for CMOS logic gates
# Operating conditions: 4.5V, 25°C
# Calculate total propagation delay from A to Z
# Assume unconnected inputs are set to allow transitions
#
# #### Enter propagation delay for circuit 4.1 (ns)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
delay_4_1 = 0.0  # Replace with actual value

# %% [markdown]
# #### Enter propagation delay for circuit 4.2 (ns)

# %%
delay_4_2 = 0.0  # Replace with actual value

# %% [markdown]
# #### Enter propagation delay for circuit 4.3 (ns)

# %%
delay_4_3 = 0.0  # Replace with actual value

# %% [markdown]
# #### Enter propagation delay for circuit 4.4 (ns)

# %%
delay_4_4 = 0.0  # Replace with actual value

# %% [markdown]
# #### Enter propagation delay for circuit 4.5 (ns)

# %%
delay_4_5 = 0.0  # Replace with actual value

# %% [markdown]
# #### Enter propagation delay for circuit 4.6 (ns)

# %%
delay_4_6 = 0.0  # Replace with actual value

# %% [markdown]
# #### Enter propagation delay for circuit 4.7 (ns)

# %%
delay_4_7 = 0.0  # Replace with actual value

# %%
import json

variables_list =[
    student_name,
    vt_plus_typical, vt_plus_min, vt_plus_max,
    vt_minus_typical, vt_minus_min, vt_minus_max,
    t_thl_typical, t_thl_max,
    t_tlh_typical, t_tlh_max,
    t_phl_typical, t_phl_max,
    t_plh_typical, t_plh_max,
    t_thl_3, t_tlh_3, t_phl_3, t_plh_3,
    delay_4_1, delay_4_2, delay_4_3, delay_4_4, delay_4_5, delay_4_6, delay_4_7
]

variables_json = json.dumps({
    "student_name": student_name,
    "vt_plus": {
        "typical": vt_plus_typical,
        "min": vt_plus_min,
        "max": vt_plus_max
    },
    "vt_minus": {
        "typical": vt_minus_typical,
        "min": vt_minus_min,
        "max": vt_minus_max
    },
    "t_thl": {
        "typical": t_thl_typical,
        "max": t_thl_max
    },
    "t_tlh": {
        "typical": t_tlh_typical,
        "max": t_tlh_max
    },
    "t_phl": {
        "typical": t_phl_typical,
        "max": t_phl_max
    },
    "t_plh": {
        "typical": t_plh_typical,
        "max": t_plh_max
    },
    "t_3": {
        "thl": t_thl_3,
        "tlh": t_tlh_3,
        "phl": t_phl_3,
        "plh": t_plh_3
    },
    "delays": {
        "4_1": delay_4_1,
        "4_2": delay_4_2,
        "4_3": delay_4_3,
        "4_4": delay_4_4,
        "4_5": delay_4_5,
        "4_6": delay_4_6,
        "4_7": delay_4_7
    }
}, indent=4)

with open('prelab3_output.json', 'w') as f:
    f.write(variables_json)
